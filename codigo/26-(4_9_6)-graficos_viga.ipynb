# %% [markdown]
# <a href="https://colab.research.google.com/github/jnramirezg/mecanica_de_solidos/blob/main/codigo/26-(4_9_6)-graficos_viga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 26. Gráficos de colores de esfuerzos y deformaciones (sección 4.9.6)
#
# |Quién | Fecha | Qué hizo |
# | ---  | ---   | ---      |
# |Juan Nicolás Ramírez, <jnramirezg@unal.edu.co> | 2022-10-10 | Conversión de código de MAXIMA a Python|
